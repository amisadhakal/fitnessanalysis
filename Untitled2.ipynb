# %%
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
# Out:
# Requirement already satisfied: pandas in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (2.3.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (3.10.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: pyparsing>=3 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=8 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: six>=1.5 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from scikit-learn) (2.2.6)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting scipy>=1.8.0
#   Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.7.2 scipy-1.15.3 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 23.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv("clean_dataset.csv")
print(df.columns)
df.head()
# Out:
# Index(['date', 'steps', 'calories_burned', 'distance_km', 'active_minutes',
#        'sleep_hours', 'heart_rate_avg', 'workout_type', 'weather_conditions',
#        'location', 'mood'],
#       dtype='object')
#          date  steps  calories_burned  distance_km  active_minutes  \
# 0  2023-01-01   4530          2543.02        16.10             613
# 1  2023-01-01  11613          1720.76         8.10             352
# 2  2023-01-01  27335          1706.35         3.57             236
# 3  2023-01-01  13459          2912.38         6.41            1329
# 4  2023-01-01  15378          3344.51        17.88              52
#
#    sleep_hours  heart_rate_avg workout_type weather_conditions location  \
# 0          1.5             176      Walking              Clear     Park
# 1          6.3             128      Cycling                Fog     Park
# 2          6.7             134         Yoga               Snow     Park
# 3         11.6             116     Swimming               Rain   Office
# 4          7.4              84     Swimming               Rain   Office
#
#       mood
# 0    Tired
# 1    Happy
# 2  Neutral
# 3    Tired
# 4  Neutral

# %%
X = df[['steps', 'sleep_hours', 'heart_rate_avg']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
inertia = []

for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 10), inertia, marker='o')
plt.xlabel("K") 
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: pillow>=8 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from pandas>=1.2->seaborn) (2026.1.post1)
# Requirement already satisfied: six>=1.5 in c:\users\amisa\downloads\fitness_d\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
cluster_names = {
    0: 'Low Activity',
    1: 'High Activity',
    2: 'Moderate Activity'
}
df['Cluster_Label'] = df['Cluster'].map(cluster_names)

# %%
df[['Cluster', 'Cluster_Label']].head()
# Out:
#    Cluster      Cluster_Label
# 0        2  Moderate Activity
# 1        2  Moderate Activity
# 2        0       Low Activity
# 3        1      High Activity
# 4        0       Low Activity

# %%
df.groupby('Cluster_Label').mean(numeric_only=True)
# Out:
#                           steps  calories_burned  distance_km  active_minutes  \
# Cluster_Label
# High Activity       6783.359728      2750.262458     9.995612      719.639881
# Low Activity       22890.162993      2750.039447     9.992097      718.931590
# Moderate Activity  15371.762507      2749.768367     9.995466      719.635980
#
#                    sleep_hours  heart_rate_avg  Cluster
# Cluster_Label
# High Activity         6.010171       98.890486      1.0
# Low Activity          5.989927       96.327392      0.0
# Moderate Activity     6.000422      155.954951      2.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(data=df, x='steps', y='heart_rate_avg', hue='Cluster_Label')
plt.show()
# Out:
# C:\Users\amisa\Downloads\fitness_d\venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.to_csv("clustered_data.csv", index=False)
